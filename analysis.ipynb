# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#               id  pol_bonus pol_coverage  pol_duration  pol_sit_duration  \
# 0  A00048679_V01       0.50         Maxi            21                 2
# 1  A00036855_V01       0.50         Maxi            19                 4
# 2  A00051293_V01       0.51      Median2             5                 1
# 3  A00054760_V01       0.50         Maxi            26                 1
# 4  A00077495_V01       0.50      Median2             5                 2
#
#   pol_pay_freq pol_payd    pol_usage pol_insee_code drv_drv2  ...  vh_weight  \
# 0      Monthly       No      Retired          64483       No  ...        790
# 1      Monthly       No      Retired          56220       No  ...       1120
# 2       Yearly       No  WorkPrivate          14106       No  ...       2210
# 3      Monthly       No      Retired          34258       No  ...       1141
# 4       Yearly       No  WorkPrivate          24064       No  ...          0
#
#    town_mean_altitude town_surface_area population  \
# ...

# %%
data.describe()
# Out:
#           pol_bonus  pol_duration  pol_sit_duration      drv_age1  \
# count  16000.000000  16000.000000      16000.000000  16000.000000
# mean       0.536357     11.143000          2.751125     54.800063
# std        0.096745      8.558651          2.375140     14.865985
# min        0.500000      1.000000          1.000000     19.000000
# 25%        0.500000      4.000000          1.000000     44.000000
# 50%        0.500000      9.000000          2.000000     55.000000
# 75%        0.500000     17.000000          3.000000     65.000000
# max        1.560000     39.000000         25.000000    100.000000
#
#            drv_age2  drv_age_lic1  drv_age_lic2        vh_age        vh_cyl  \
# count  16000.000000  16000.000000  16000.000000  15999.000000  16000.000000
# mean      15.685375     32.579313      9.187188      9.695418   1641.898875
# std       24.124951     13.473727     17.056325      7.137755    457.950580
# ...

# %%
clean_data = data[['drv_age1', 'drv_age_lic1', 'vh_age', 'vh_value', 'vh_speed']]

# %%
np.where(clean_data['vh_age'].isnull())
# Out:
# (array([414], dtype=int64),)
